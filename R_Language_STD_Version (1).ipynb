# %% [markdown]
# ![WhatsApp Image 2023-01-05 at 10.09.57 PM.jpeg](data:image/jpeg;base64,...)
# <center>
#
# <p>
#
# # **Introduction to R** <br>
# In the following notebook, there are the basics of the language R<br>
# Abdelrahman Sobeih <br>
# Maryam Almetnawy<br>
# </p></center>

# %% [markdown]
# ## Arithmatic Operations and Variable Assignment with R
# A variable allows us to store a value or an object which you can use later. When assigning a variable in R, we usually denote it by <- (e.g. `x <-5`; so x gets 5)
#
# In other programming language, it is common to use `=` as an assignment operator. In R, we can use both = and `<-` as assignment operators.
# However, `<-` is preferred in most cases because the `=` operator can be forbidden in some context in R.
#
# Arithmatic Operations:
# *   Addition: `+`
# *   Subtraction: `-`
#
# *   Multiplication: `*`
#
# *   Division: `/`
# *   Exponentiation: `^`
#
#
# *   Modulo: `%%`

# %%
x <- 5
y <- 6
r <- x + y
print(r)
# Out:
# [1] 11

# %% [markdown]
# ## Basic data types in R
# R works with numerous data types. Some of the most basic types to get started are:
#
# *   Decimal values like 4.5 are called numerics.
# *   Whole numbers like 4 are called integers. Integers are also numerics.
# *   Boolean values (TRUE or FALSE) are called logical.
# *   Text (or string) values are called characters and they have to be writtnen between quotations or double quotations.
#
# when you added 5 + "six", you get an error due to a mismatch in data types. You can avoid such embarrassing situations by checking the data type of a variable beforehand. You can do this with the class() function.
#
# ***Note that R is case sensitive!***

# %%
x <- 4.2
y <- 3
b <-  TRUE 
st <- "Hello"

# %%
class(x)
# Out:
# [1] "numeric"

# %%
class(y)
# Out:
# [1] "numeric"

# %%
class(b)
# Out:
# [1] "logical"

# %%
class(st)
# Out:
# [1] "character"

# %% [markdown]
# ## Vectors
# Vectors are one-dimension arrays that can hold numeric data, character data, or logical data. In other words, a vector is a simple tool to store data.
#
# In R, you create a vector with the combine function c(). You place the vector elements separated by a comma between the parentheses. For example: numeric_vector <- c(1, 2, 3) character_vector <- c("a", "b", "c")
#
# Once you have created these vectors in R, you can use them to do calculations.

# %%
#examples of vectors
numeric_vector <- c(100, 200, 450)
character_vector <- c("Monday", "Tuesday", "Wednesday")
numeric_vector2 <- c(50, 120, 300)
print(numeric_vector - numeric_vector2) #the calculation we performed on the vectors
print(c(40,200) + c(10, 200)) #another calculation
print(c(40 + 10, 200 + 200)) #another way of doing the same calculation above
#another way of caculating 
a <- c(1, 2, 3)  
b <- c(4, 5, 6) 
c <- a + b
print(c)
# Out:
# [1]  50  80 150
# [1]  50 400
# [1]  50 400
# [1] 5 7 9

# %% [markdown]
# You can add elements to your vector using append(). Check out the following example:

# %%
ex = c("Ameen", "Tina", "Talia")
cat("The original vector: ",ex, "\n")
ex = append(ex, "Mohammed")
cat("After adding another name: ",ex, "\n")
# Out:
# The original vector:  Ameen Tina Talia
# After adding another name:  Ameen Tina Talia Mohammed

# %% [markdown]
# we created a vector. Each vector element refers to a day of the week but it is hard to tell which element belongs to which day. It would be nice if you could show that in the vector itself. You can give a name to the elements of a vector with the names() function. Have a look at this example:

# %%
#using the example above
names(numeric_vector) <- character_vector
print(numeric_vector)
print("-----------------------------")
#using a different example with new vectors
some_vector <- c("John Doe", "Gamer") 
names(some_vector) <- c("Name", "Profession")
print(some_vector)
# Out:
#    Monday   Tuesday Wednesday
#       100       200       450
# [1] "-----------------------------"
#       Name Profession
# "John Doe"    "Gamer"

# %%
some_vector <- c("John Doe", "Gamer") 
names(some_vector) <- c("Name", "Profession")
print(some_vector)
# Out:
#       Name Profession
# "John Doe"    "Gamer"

# %% [markdown]
# ###Printing in R
# If you want to print, you can use the print() function. However, sometimes you wnat to concatenate the messages with variables, in this case we cannot use the regular print() we need to use either print(paste()) or cat().
# Note that cat() does not print to the next line unlike print(paste()), so if you want to move to the next line we have to specify it.
# Check out the following exmples:

# %%
x <- 4
y <- 6 
print(paste("the number that the variable x has is: ", x)) #concatenating using print(paste())
cat("the number that the variable y has is: ", y) #concatenating using cat()
# Out:
# [1] "the number that the variable x has is:  4"
# the number that the variable y has is:  6

# %% [markdown]
# ### Entering Values from the User
# In some cases, you want to ask the user to inter a value, you can use the readline(prompt="the message for the user") function with the argument "prompot". Note that condition is always in the "character" datatype so if we need aa different datatype we need to convert it.
#
#
# Check out the following example to understad more:

# %%
xx <- readline(prompt="Enter name: ")
yy <- readline(prompt="Enter age: ")
# convert character into integer
yy <- as.integer(yy)
print(paste("Hi,", xx, "next year you will be", yy+1, "years old.")) #printing with concatenation using print(pase())
cat("Hi,", xx, "next year you will be", yy+1, "years old.") #printing with concatenation using cat()
# Out:
# Enter name: maryam
# Enter age: 20
# [1] "Hi, maryam next year you will be 21 years old."
# Hi, maryam next year you will be 21 years old.

# %% [markdown]
# ###Selection by comparison - By making use of comparison operators
# we can approach the previous question in a more proactive way. The (logical) comparison operators known to R are:
#
#
# *   `<` for less than
#
# *   `>` for greater than
#
# *   `<=` for less than or equal to
# *   `>=` for greater than or equal to
#
#
# *  `==` for equal to each other
#
#
# *  `!=` not equal to
#
#
# stating 6 > 5 returns TRUE. The nice thing about R is that you can use these comparison operators also on vectors. For example: c(4, 5, 6) > 5 which will return FALSE FALSE TRUE This command tests for every element of the vector if the condition stated by the comparison operator is TRUE or FALSE.

# %%
6 > 3 
c(4, 5, 6) > 5
# Out:
# [1] TRUE
# [1] FALSE FALSE  TRUE

# %% [markdown]
# ###if else statements
# Notice the following syntax:
# ```
# if (test_expression) {
# statement1
# }
# else {
# statement2
# }
# ```

# %%
#an example of an if statement
x <- 5
if(x > 0){
print("Positive number")
}
#an example of if else statements
x <- -5
if(x > 0){
print("Non-negative number")
} else {
print("Negative number")
}
#the same conndition can also be written like the following:
if(x > 0) print("Non-negative number") else print("Negative number")
# Out:
# [1] "Positive number"
# [1] "Negative number"
# [1] "Negative number"

# %% [markdown]
# ### Multiple if…else statements
# The if…else ladder (if…else…if) statement allows you execute a block of code among more than 2 alternatives
#
# The syntax of if…else statement is:
#
#
# ```
# if ( test_expression1) {
# statement1
# } else if ( test_expression2) {
# statement2
# } else if ( test_expression3) {
# statement3
# } else {
# statement4
# }
# ```

# %%
#an example of a multiple if else statements
x <- 0
if (x < 0) {
print("Negative number")
} else if (x > 0) {
print("Positive number")
} else
print("Zero")
# Out:
# [1] "Zero"

# %% [markdown]
# ### While Loops
# An expression is evaluated and the body of the loop is entered if the result is TRUE.
# The statements inside the loop are executed and the flow returns to evaluate the expression again.
# This is repeated each time until expression evaluates to FALSE, in which case, the loop exits.
#
# The syntax of a while loop:
# ```
# while (test_expression)
# {
# statement
# }
# ```

# %%
#an example of a normal while loop
i = 0
while(i < 5) {
print(i)
i <- i + 1
}
# Out:
# [1] 0
# [1] 1
# [1] 2
# [1] 3
# [1] 4

# %%
#another example of a loop
v <- c(2,3,4)
i = 0
while(i < 5) {
  v <- v*2
  print(v)
print(i)
i <- i + 1
}
# Out:
# [1] 4 6 8
# [1] 0
# [1]  8 12 16
# [1] 1
# [1] 16 24 32
# [1] 2
# [1] 32 48 64
# [1] 3
# [1]  64  96 128
# [1] 4

# %% [markdown]
# ### For Loops
# A sequence is a vector and val takes on each of its value during the loop. In each iteration, statement is evaluated.
#
# syntax of for loop:
# ```
# for (val in sequence)
# {
# statement
# }
#
# ```

# %%
#an example
for(i  in 1:5) {
  print(i)
}
# Out:
# [1] 1
# [1] 2
# [1] 3
# [1] 4
# [1] 5

# %%
#another example
for(i  in c(3,5,2,9)) {
  print(i)
}
# Out:
# [1] 3
# [1] 5
# [1] 2
# [1] 9

# %% [markdown]
# ## Functions in R
# Functions are used to logically break our code into simpler parts which become easy to maintain and understand.
# It is pretty straightforward to create your own function in R programming.
#
# The syntax for Writing Functions in R:
# ```
# func_name <- function (argument) {
# statement
# }
# ```

# %%
# function to print x raised to the power y
pow <- function(x, y) {
result <- x^y
print(paste(x,"raised to the power", y, "is", result))
}

# %%
#testing the funcion we have
pow(2,3)
# Out:
# [1] "2 raised to the power 3 is 8"

# %%
add <- function(x,y) {
  r = x + y
  return(r)
}

# %%
add(5,3)
# Out:
# [1] 8

# %%
add(x = 4, y = 1) #we could specify the arguments
# Out:
# [1] 5

# %%
subtract <- function(x,y) {
  return(x-y)
}

# %%
subtract(5,2)
# Out:
# [1] 3

# %%
subtract(y = 4, x = 2) #we can specify the arguments which the that case the order doesn't matter
# Out:
# [1] -2

# %% [markdown]
# ### Matrices
# In R, a matrix is a collection of elements of the same data type (numeric, character, or logical) arranged into a fixed number of rows and columns.
#
# Since you are only working with rows and columns, a matrix is called two-dimensional. You can construct a matrix in R with the matrix() function. Consider the following example: matrix(1:9, byrow = TRUE, nrow = 3)
#
# In the matrix() function:
#
# *   The first argument is the collection of elements that R will arrange into the rows and columns of the matrix. Here, we use 1:9 which is a shortcut for c(1, 2, 3, 4, 5, 6, 7, 8, 9)
# *   The argument byrow indicates that the matrix is filled by the rows. If we want the matrix to be filled by the columns, we just place byrow = FALSE.
#
# *  The third argument nrow indicates that the matrix should have three rows.

# %%
matrix(1:9, byrow = TRUE, nrow = 3)
# Out:
#      [,1] [,2] [,3]
# [1,] 1    2    3
# [2,] 4    5    6
# [3,] 7    8    9

# %%
matrix(1:9, byrow = FALSE, nrow = 3)
# Out:
#      [,1] [,2] [,3]
# [1,] 1    4    7
# [2,] 2    5    8
# [3,] 3    6    9

# %% [markdown]
# ### Naming a matrix
# To help you remember what is stored in your matrix. which helps you to read the data, but it is also useful to select certain elements from the matrix.
#
# Similar to vectors, you can add names for the rows and the columns of a matrix:
# ```
# rownames(my_matrix) <- row_names_vector
# colnames(my_matrix) <- col_names_vector
# ```
# We went ahead and prepared two vectors for you: regions, and titles. We used the the following to help us naming the matrix:
#
# *   colnames() to name the columns of star_wars_matrix with the region vector.
#
# *   rownames() to name the rows of star_wars_matrix with the titles vector.

# %%
# Box office Star Wars (in millions!) 
new_hope <- c(460.998, 314.4) 
empire_strikes <- c(290.475, 247.900) 
return_jedi <- c(309.306, 165.8)  
# Create box_office 
box_office <- c(new_hope, empire_strikes, return_jedi)  
# Construct star_wars_matrix 
star_wars_matrix <- matrix(box_office, byrow = TRUE, nrow = 3)  
star_wars_matrix
# Out:
#      [,1]    [,2]
# [1,] 460.998 314.4
# [2,] 290.475 247.9
# [3,] 309.306 165.8

# %%
# Vectors regions and titles, used for naming
regions <- c("US", "non-US") 
titles <- c("A New Hope", "The Empire Strikes Back", "Return of the Jedi") 
# Name the columns with region
colnames(star_wars_matrix) <- regions
# Name the rows with titles 
rownames(star_wars_matrix) <- titles 	
# Print out star_wars_matrix 
star_wars_matrix
# Out:
#                         US      non-US
# A New Hope              460.998 314.4
# The Empire Strikes Back 290.475 247.9
# Return of the Jedi      309.306 165.8

# %% [markdown]
# ## Basic Plots with R

# %% [markdown]
# ### Line Graphs

# %%
# Create some variables
x <- 1:10
y1 <- x*x
y2  <- 2*y1

# %%
# Create a basic stair steps plot 
plot(x, y1, type = "s")
# Show line
plot(x, y1, type = "l", pch = 19, 
     col = "red", xlab = "x", ylab = "y")
# Show both points and line
plot(x, y1, type = "b", pch = 19, 
     col = "red", xlab = "x", ylab = "y")
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ### Pie Charts

# %%
# Create data for the graph.
x <- c(44, 12, 24, 20)
labels <- c("London", "New York", "Singapore", "Mumbai")

# Plot the chart with title
pie(x, labels, main = "City pie chart")
# Out:
# Plot with title “City pie chart”

# %%
#installing a pakage
install.packages("plotrix")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Get the library.
library(plotrix)

# Create data for the graph.
x <-  c(21, 62, 10,53)
lbl <-  c("London","New York","Singapore","Mumbai")

# Plot the chart.
pie3D(x,labels = lbl,explode = 0.1, main = "Pie Chart of Countries")
# Out:
# Plot with title “Pie Chart of Countries”

# %% [markdown]
# ### Bar Plots

# %%
# barchart with added parameters
var <- c(21, 17, 22, 29, 23, 16, 10)
barplot(var,
main = "Maximum Temperatures in a Week",
xlab = "Degree Celsius",
ylab = "Day",
names.arg = c("Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"),
col = "darkred",
horiz = FALSE) #we can make horiz TRUE to make it horizontal
# Out:
# Plot with title “Maximum Temperatures in a Week”

# %%
age <- c(17,18,18,17,18,19,18,16,18,18)
barplot(table(age),
main="Age Count of 10 Students",
xlab="Age",
ylab="Count",
border="black",
col="blue",
density=10
)
# Out:
# Plot with title “Age Count of 10 Students”

# %% [markdown]
# ### Scatter Plots

# %%
x <- c(5,7,8,7,2,2,9,4,11,12,9,6)
y <- c(99,86,87,88,111,103,87,94,78,77,85,86)
plot(x, y, main="Observation of Cars", xlab="Car age", ylab="Car speed")
# Out:
# Plot with title “Observation of Cars”

# %%
# day one, the age and speed of 12 cars:
x1 <- c(5,7,8,7,2,2,9,4,11,12,9,6)
y1 <- c(99,86,87,88,111,103,87,94,78,77,85,86)

# day two, the age and speed of 15 cars:
x2 <- c(2,2,8,1,15,8,12,9,7,3,11,4,7,14,12)
y2 <- c(100,105,84,105,90,99,90,95,94,100,79,112,91,80,85)

x3 <- c(1,11,2,3,4,15,12,7,9,19,3,5,8,13,1)
y3 <- c(111,91,82,95,84,92,113,79,84,102,89,101,97,83,99)
plot(x1, y1, main="Observation of Cars", xlab="Car age", ylab="Car speed", col="red", cex=2)
points(x2, y2, col="blue", cex=2)
points(x3, y3, col="black", cex=2)
# Out:
# Plot with title “Observation of Cars”

# %% [markdown]
# ## Some Basic Statistics
# We can get some basic statistics on a vector, for example:
#
#
# *  mean()
# *  median()
# *  sum()
# *  min()
# *  max()

# %%
st <- c(1,13,2,19,12,5,7,8)

# %%
cat('the mean is:', mean(st), "\n")
cat('the median is:', median(st), "\n")
cat('the sum is:', sum(st), "\n")
cat('the minimum is:', min(st), "\n")
cat('the maximum is:', max(st), "\n")
# Out:
# the mean is: 8.375
# the median is: 7.5
# the sum is: 67
# the minimum is: 1
# the maximum is: 19

# %%
print(paste('the mean is:', mean(st)))
print(paste('the median is:', median(st)))
print(paste('the sum is:', sum(st)))
print(paste('the minimum is:', min(st)))
print(paste('the maximum is:', max(st)))
# Out:
# [1] "the mean is: 8.375"
# [1] "the median is: 7.5"
# [1] "the sum is: 67"
# [1] "the minimum is: 1"
# [1] "the maximum is: 19"

# %% [markdown]
# ## Questions:
# **1. Create the following matrix:**
#
# ![Screenshot 2023-01-10 at 5.37.14 PM.png](data:image/png;base64,...)

# %% [markdown]
# **2. create a variable `"first"` for the follwing vector: 12,8,16,19**

# %% [markdown]
# **3. subtract 3 from the vector above and save the result in another variable named `"second"`**

# %% [markdown]
# **4. Plot a bar chart for `"second"` variable with these names respictively for each number: CS, MBA, IT, DA and change the color to "blue"**

# %% [markdown]
# **5. Plot the `"first"` variable against this variable:  `third <- c(11,10,15,22)` (using a scatterplot) and connect the points with a line**

# %% [markdown]
# **6. Ask the user to enter three float(double) values and plot them in a pie chart. Hint: use `as.double()`**
